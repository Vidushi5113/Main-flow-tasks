# %% [markdown]
# Create a bar chart and a line chart using
# Matplotlib to visualize data from a Pandas
# DataFrame. Customize the charts with
# labels, titles, and legends.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/householdtask3.csv')

# %%
data1=pd.DataFrame({
    'Name':['Aniket','Kabir','Shivani','Shivangi','Sukriti','Prateek','Ritik'],
    'year':[2017,2018,2019,2020,2021,2022,2023],
    'Age':[23,21,22,21,21,22,21],
    'City':['Bhopal','Pune','Mumbai','Delhi','Pune','Mumbai','Bhopal'],
    'Expenses':[22000,23500,26000,23500,26000,22000,23500],
    'Salary':[22000,23500,26000,23500,26000,22000,23500],
    'Side Income':[8000,5000,10000,12000,7000,5000,8000]
})

# %%
data1
# Out:
#        Name  year  Age    City  Expenses  Salary  Side Income
# 0    Aniket  2017   23  Bhopal     22000   22000         8000
# 1     Kabir  2018   21    Pune     23500   23500         5000
# 2   Shivani  2019   22  Mumbai     26000   26000        10000
# 3  Shivangi  2020   21   Delhi     23500   23500        12000
# 4   Sukriti  2021   21    Pune     26000   26000         7000
# 5   Prateek  2022   22  Mumbai     22000   22000         5000
# 6     Ritik  2023   21  Bhopal     23500   23500         8000

# %%
from matplotlib import pyplot as plt
_df_17['Expenses'].plot(kind='line', color='g',figsize=(8, 4), title='Expenses',linestyle='--')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Expenses

from matplotlib import pyplot as plt
data1['Expenses'].plot(kind='hist', bins=20,color='g',title='Expenses')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.head(5)
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# 2   2.3   16747        21145       13402    14408
# 3   2.8   31308        29855       18917    18266
# 4   3.0   49106        46561       26870    24672

# %%
data
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
plt.bar(data['year'],data['expenditure'], color = 'g',width=0.8,linewidth=2)
plt.xlabel('year')
plt.ylabel('expenditure')
plt.title('Expenditure in different years')
plt.show()
